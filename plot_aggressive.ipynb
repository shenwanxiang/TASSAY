# %%
import seaborn as sns
from statannot import add_stat_annotation
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
sns.set(style='white',font_scale=1.5,)

# %%
df = pd.read_excel('./aggresive.xlsx')

# %%
df = df.set_index('PID')

# %%
set1 =  ['Her2', 'ER', 'PR', 'SCRIB', 'WASF3']

hue = 'Group'

x = 'Total Protein'
y = 'Relative intensity'
hue_order = set1
order = ['more aggresive', 'less aggresive']
box_pairs = [((col, "more aggresive"), (col, "less aggresive")) for col in set1 ]

res= []
for i in set1:
    df1 = df[i].to_frame(name = y)
    df1[x] = i
    res.append(df1)
    
data = pd.concat(res)
data = data.join(df['Group'])

# %%
fig, ax = plt.subplots(figsize= (12,6))

sns.stripplot(x=x, y=y, 
              data=data, jitter=True, hue = hue,ax = ax,
              split=True,linewidth=1,edgecolor='gray')



sns.boxenplot(data=data, x=x, y=y, hue = hue, ax= ax, width = 0.8, saturation = 1,)

test_results = add_stat_annotation(ax, data=data, x=x, y=y, hue=hue,
                                   box_pairs=box_pairs,
                                   test='Mann-Whitney-gt', text_format='star',
                                   loc='outside', verbose=2)

handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = plt.legend(handles[0:2], labels[0:2], bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation=45, ha='right')

plt.savefig('1-mer.pdf', dpi=400, bbox_inches='tight')
# Out:
# /home/shenwanxiang/.local/lib/python3.6/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ER_more aggresive v.s. ER_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=4.600e+01
# Her2_more aggresive v.s. Her2_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=5.000e+01
# PR_more aggresive v.s. PR_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=4.900e+01
# SCRIB_more aggresive v.s. SCRIB_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=6.692e-01 U_stat=7.100e+01
# WASF3_more aggresive v.s. WASF3_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=3.900e+01

# %%
set1 =  ['Her2-SHC', 'Her2-GRB2',
       'ER-GATA3', 'ER-FOXA1', 'PR-TIF2', 'PR-SRC-1', 'SCRIB-VANGL1',
       'SCRIB-NOS1AP', 'WASF3-CYFIP1', 'WASF3-NCKAP1',]

hue = 'Group'

x = '2-mer'
y = 'Relative intensity'
hue_order = set1
order = ['more aggresive', 'less aggresive']
box_pairs = [((col, "more aggresive"), (col, "less aggresive")) for col in set1 ]

res= []
for i in set1:
    df1 = df[i].to_frame(name = y)
    df1[x] = i
    res.append(df1)
    
data = pd.concat(res)
data = data.join(df['Group'])

fig, ax = plt.subplots(figsize= (12,6))

sns.stripplot(x=x, y=y, 
              data=data, jitter=True, hue = hue,ax = ax,
              split=True,linewidth=1,edgecolor='gray')



sns.boxenplot(data=data, x=x, y=y, hue = hue, ax= ax, width = 0.8, saturation = 1,)

test_results = add_stat_annotation(ax, data=data, x=x, y=y, hue=hue,
                                   box_pairs=box_pairs,
                                   test='Mann-Whitney-gt', text_format='star',
                                   loc='outside', verbose=2)

handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = plt.legend(handles[0:2], labels[0:2], bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation=45, ha='right')

plt.savefig('2-mer.pdf', dpi=400, bbox_inches='tight')
# Out:
# /home/shenwanxiang/.local/lib/python3.6/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# WASF3-NCKAP1_more aggresive v.s. WASF3-NCKAP1_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.851e-02 U_stat=9.800e+01
# WASF3-CYFIP1_more aggresive v.s. WASF3-CYFIP1_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=2.811e-02 U_stat=9.600e+01
# Her2-GRB2_more aggresive v.s. Her2-GRB2_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=5.090e-01 U_stat=7.900e+01
# Her2-SHC_more aggresive v.s. Her2-SHC_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=5.090e-01 U_stat=7.900e+01
# ER-GATA3_more aggresive v.s. ER-GATA3_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=7.000e+01
# ER-FOXA1_more aggresive v.s. ER-FOXA1_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=7.588e-01 U_stat=7.600e+01
# PR-TIF2_more aggresive v.s. PR-TIF2_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=6.800e+01
# PR-SRC-1_more aggresive v.s. PR-SRC-1_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=6.800e+01
# SCRIB-VANGL1_more aggresive v.s. SCRIB-VANGL1_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.786e-01 U_stat=8.600e+01
# SCRIB-NOS1AP_more aggresive v.s. SCRIB-NOS1AP_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.276e-01 U_stat=8.800e+01

# %%
set1 =  ['Her2-GRB2-SHC',
       'ER-GATA3-FOXA1', 'PR-TIF2-SRC-1', 'SCRIB-VANGL1-NOS1AP',
       'WASF3-CYFIP1-NCKAP1']

hue = 'Group'

x = '3-mer'
y = 'Relative intensity'
hue_order = set1
order = ['more aggresive', 'less aggresive']
box_pairs = [((col, "more aggresive"), (col, "less aggresive")) for col in set1 ]

res= []
for i in set1:
    df1 = df[i].to_frame(name = y)
    df1[x] = i
    res.append(df1)
    
data = pd.concat(res)
data = data.join(df['Group'])

fig, ax = plt.subplots(figsize= (12,6))

sns.stripplot(x=x, y=y, 
              data=data, jitter=True, hue = hue,ax = ax,
              split=True,linewidth=1,edgecolor='gray')



sns.boxenplot(data=data, x=x, y=y, hue = hue, ax= ax, width = 0.8, saturation = 1,)

test_results = add_stat_annotation(ax, data=data, x=x, y=y, hue=hue,
                                   box_pairs=box_pairs,
                                   test='Mann-Whitney-gt', text_format='star',
                                   loc='outside', verbose=2)

handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = plt.legend(handles[0:2], labels[0:2], bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation=45, ha='right')

plt.savefig('3-mer.pdf', dpi=400, bbox_inches='tight')
# Out:
# /home/shenwanxiang/.local/lib/python3.6/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ER-GATA3-FOXA1_more aggresive v.s. ER-GATA3-FOXA1_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=4.293e-01 U_stat=7.500e+01
# Her2-GRB2-SHC_more aggresive v.s. Her2-GRB2-SHC_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=6.063e-01 U_stat=7.200e+01
# PR-TIF2-SRC-1_more aggresive v.s. PR-TIF2-SRC-1_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=5.200e+01
# SCRIB-VANGL1-NOS1AP_more aggresive v.s. SCRIB-VANGL1-NOS1AP_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=9.310e-03 U_stat=9.800e+01
# WASF3-CYFIP1-NCKAP1_more aggresive v.s. WASF3-CYFIP1-NCKAP1_less aggresive: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=8.515e-04 U_stat=1.080e+02

# %%
df.columns
# Out:
# Index(['Group', 'Her2', 'ER', 'PR', 'SCRIB', 'WASF3', 'Her2-SHC', 'Her2-GRB2',
#        'ER-GATA3', 'ER-FOXA1', 'PR-TIF2', 'PR-SRC-1', 'SCRIB-VANGL1',
#        'SCRIB-NOS1AP', 'WASF3-CYFIP1', 'WASF3-NCKAP1', 'Her2-GRB2-SHC',
#        'ER-GATA3-FOXA1', 'PR-TIF2-SRC-1', 'SCRIB-VANGL1-NOS1AP',
#        'WASF3-CYFIP1-NCKAP1'],
#       dtype='object')
