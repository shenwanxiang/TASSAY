# %%
import seaborn as sns
from statannot import add_stat_annotation
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
sns.set(style='white',font_scale=1.5,)

# %%
df = pd.read_excel('./tumor vs normal.xlsx')

# %%
#df = df.set_index('PID')

# %%
set1 =  ['Her2', 'ER', 'PR', 'SCRIB', 'WASF3']

hue = 'Group'

x = 'Total Protein'
y = 'Relative intensity'
hue_order = set1
order = ['Tumor', 'Normal']
box_pairs = [((col, "Tumor"), (col, "Normal")) for col in set1 ]

res= []
for i in set1:
    df1 = df[i].to_frame(name = y)
    df1[x] = i
    res.append(df1)
    
data = pd.concat(res)
data = data.join(df['Group'])

# %%
fig, ax = plt.subplots(figsize= (12,6))

sns.stripplot(x=x, y=y, 
              data=data, jitter=True, hue = hue,ax = ax,
              split=True,linewidth=1,edgecolor='gray')



sns.boxenplot(data=data, x=x, y=y, hue = hue, ax= ax, width = 0.8, saturation = 1,)

test_results = add_stat_annotation(ax, data=data, x=x, y=y, hue=hue,
                                   box_pairs=box_pairs, 
                                   test='Mann-Whitney-gt', text_format='star',
                                   loc='outside', verbose=2)

handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = plt.legend(handles[0:2], labels[0:2], bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation=45, ha='right')

plt.savefig('1-mer.pdf', dpi=400, bbox_inches='tight')
# Out:
# /home/shenwanxiang/.local/lib/python3.6/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ER_Tumor v.s. ER_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=4.170e-06 U_stat=3.660e+02
# Her2_Tumor v.s. Her2_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=9.173e-05 U_stat=3.420e+02
# PR_Tumor v.s. PR_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=8.876e-01 U_stat=2.260e+02
# SCRIB_Tumor v.s. SCRIB_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=6.268e-05 U_stat=3.450e+02
# WASF3_Tumor v.s. WASF3_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.000e+00 U_stat=2.050e+02

# %%
set1 =  ['Her2-SHC', 'Her2-GRB2',
       'ER-GATA3', 'ER-FOXA1', 'PR-TIF2', 'PR-SRC-1', 'SCRIB-VANGL1',
       'SCRIB-NOS1AP', 'WASF3-CYFIP1', 'WASF3-NCKAP1',]

hue = 'Group'

x = '2-mer'
y = 'Relative intensity'
hue_order = set1
order = ['Tumor', 'Normal']
box_pairs = [((col, "Tumor"), (col, "Normal")) for col in set1 ]

res= []
for i in set1:
    df1 = df[i].to_frame(name = y)
    df1[x] = i
    res.append(df1)
    
data = pd.concat(res)
data = data.join(df['Group'])

fig, ax = plt.subplots(figsize= (12,6))

sns.stripplot(x=x, y=y, 
              data=data, jitter=True, hue = hue,ax = ax,
              split=True,linewidth=1,edgecolor='gray')



sns.boxenplot(data=data, x=x, y=y, hue = hue, ax= ax, width = 0.8, saturation = 1,)

test_results = add_stat_annotation(ax, data=data, x=x, y=y, hue=hue,
                                   box_pairs=box_pairs,
                                   test='Mann-Whitney-gt', text_format='star',
                                   loc='outside', verbose=2)

handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = plt.legend(handles[0:2], labels[0:2], bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation=45, ha='right')

plt.savefig('2-mer.pdf', dpi=400, bbox_inches='tight')
# Out:
# /home/shenwanxiang/.local/lib/python3.6/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# WASF3-NCKAP1_Tumor v.s. WASF3-NCKAP1_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.645e-03 U_stat=3.225e+02
# WASF3-CYFIP1_Tumor v.s. WASF3-CYFIP1_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.558e-02 U_stat=2.995e+02
# Her2-GRB2_Tumor v.s. Her2-GRB2_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=9.839e-06 U_stat=3.630e+02
# Her2-SHC_Tumor v.s. Her2-SHC_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=5.628e-06 U_stat=3.670e+02
# ER-GATA3_Tumor v.s. ER-GATA3_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=4.479e-07 U_stat=3.810e+02
# ER-FOXA1_Tumor v.s. ER-FOXA1_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=5.745e-06 U_stat=3.640e+02
# PR-TIF2_Tumor v.s. PR-TIF2_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=2.374e-04 U_stat=3.390e+02
# PR-SRC-1_Tumor v.s. PR-SRC-1_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=5.395e-05 U_stat=3.510e+02
# SCRIB-VANGL1_Tumor v.s. SCRIB-VANGL1_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=7.548e-02 U_stat=2.805e+02
# SCRIB-NOS1AP_Tumor v.s. SCRIB-NOS1AP_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=5.882e-03 U_stat=3.100e+02

# %%
set1 =  ['Her2-GRB2-SHC',
       'ER-GATA3-FOXA1', 'PR-TIF2-SRC-1', 'SCRIB-VANGL1-NOS1AP',
       'WASF3-CYFIP1-NCKAP1']

hue = 'Group'

x = '3-mer'
y = 'Relative intensity'
hue_order = set1
order = ['Tumor', 'Normal']
box_pairs = [((col, "Tumor"), (col, "Normal")) for col in set1 ]

res= []
for i in set1:
    df1 = df[i].to_frame(name = y)
    df1[x] = i
    res.append(df1)
    
data = pd.concat(res)
data = data.join(df['Group'])

fig, ax = plt.subplots(figsize= (12,6))

sns.stripplot(x=x, y=y, 
              data=data, jitter=True, hue = hue,ax = ax,
              split=True,linewidth=1,edgecolor='gray')



sns.boxenplot(data=data, x=x, y=y, hue = hue, ax= ax, width = 0.8, saturation = 1,)

test_results = add_stat_annotation(ax, data=data, x=x, y=y, hue=hue,
                                   box_pairs=box_pairs,
                                   test='Mann-Whitney-gt', text_format='star',
                                   loc='outside', verbose=2)

handles, labels = ax.get_legend_handles_labels()

# When creating the legend, only use the first two elements
# to effectively remove the last two.
l = plt.legend(handles[0:2], labels[0:2], bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
plt.xticks(rotation=45, ha='right')

plt.savefig('3-mer.pdf', dpi=400, bbox_inches='tight')
# Out:
# /home/shenwanxiang/.local/lib/python3.6/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# ER-GATA3-FOXA1_Tumor v.s. ER-GATA3-FOXA1_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.033e-06 U_stat=3.710e+02
# Her2-GRB2-SHC_Tumor v.s. Her2-GRB2-SHC_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=6.454e-06 U_stat=3.610e+02
# PR-TIF2-SRC-1_Tumor v.s. PR-TIF2-SRC-1_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.867e-05 U_stat=3.535e+02
# SCRIB-VANGL1-NOS1AP_Tumor v.s. SCRIB-VANGL1-NOS1AP_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.011e-03 U_stat=3.205e+02
# WASF3-CYFIP1-NCKAP1_Tumor v.s. WASF3-CYFIP1-NCKAP1_Normal: Mann-Whitney-Wilcoxon test greater with Bonferroni correction, P_val=1.497e-03 U_stat=3.165e+02
